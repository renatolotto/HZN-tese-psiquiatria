# %%
import pandas as pd

# %%
df_rod = pd.read_excel('Base Faturamento.xlsx',dtype={'CNPJ':object})

# %%
df_rod.head()
# Out:
#                                        Nome Fantasia  \
# 0           CLINICA DE PSICOTERAPIA BREVE E DEPRESAO
# 1                   FAZENDA DO SENHOR JESUS PACTOPOA
# 2  CLINICA TEMPO TERAPIA MEDICA E PSICO ORGANIZAC...
# 3                             UP CLINICAS ASSOCIADAS
# 4                          INSTITUTO FERNANDO PESSOA
#
#                                         Razão Social            CNPJ  \
# 0  CLINICA DOUTOR NELIO TOMBINI PSIQUIATRIA E PSI...  97260095000114
# 1  PACTO POA PROGRAMA DE AUXILIO COMUNITARIO TERA...  97134480000204
# 2                   PRO SANO ASSISTENCIA MEDICA LTDA  96778279000108
# 3                  UP UNIDADE DE PSQUIATRIA LTDA EPP  95880407000167
# 4  IAFEC INST AT FAM ESC COMPSIQPSIC E EDUSOC SIM...  94576691000110
#
#              DS_FAIXA_FATURAMENTO  Vinci Quality check 97?
# 0    De R$3.600.001 a R$5.000.000    NaN           NaN
# 1  De R$10.000.001 a R$25.000.000    NaN           NaN
# 2   De R$5.000.001 a R$10.000.000    NaN           NaN
# ...

# %%
df_rod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Nome Fantasia         414 non-null    object
#  1   Razão Social          413 non-null    object
#  2   CNPJ                  408 non-null    object
#  3   DS_FAIXA_FATURAMENTO  411 non-null    object
#  4   Vinci                 36 non-null     float64
#  5   Quality check         36 non-null     object
#  6   97?                   413 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 22.8+ KB

# %%
df_fe = pd.read_excel('Base Faturamento_v2.xlsx',dtype={'CNPJ':object})

# %%
df_fe.head()
# Out:
#                                        Nome Fantasia  \
# 0           CLINICA DE PSICOTERAPIA BREVE E DEPRESAO
# 1                   FAZENDA DO SENHOR JESUS PACTOPOA
# 2  CLINICA TEMPO TERAPIA MEDICA E PSICO ORGANIZAC...
# 3                             UP CLINICAS ASSOCIADAS
# 4                          INSTITUTO FERNANDO PESSOA
#
#                                         Raz�o Social            CNPJ  \
# 0  CLINICA DOUTOR NELIO TOMBINI PSIQUIATRIA E PSI...  97260095000114
# 1  PACTO POA PROGRAMA DE AUXILIO COMUNITARIO TERA...  97134480000204
# 2                   PRO SANO ASSISTENCIA MEDICA LTDA  96778279000108
# 3                  UP UNIDADE DE PSQUIATRIA LTDA EPP  95880407000167
# 4  IAFEC INST AT FAM ESC COMPSIQPSIC E EDUSOC SIM...  94576691000110
#
#            CNPJ.1 check            DS_FAIXA_FATURAMENTO  Vinci Quality check  \
# 0  97260095000114     0    De R$3.600.001 a R$5.000.000    NaN           NaN
# ...

# %%
df_fe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Nome Fantasia         414 non-null    object
#  1   Raz�o Social          413 non-null    object
#  2   CNPJ                  408 non-null    object
#  3   CNPJ.1                407 non-null    object
#  4   check                 413 non-null    object
#  5   DS_FAIXA_FATURAMENTO  411 non-null    object
#  6   Vinci                 36 non-null     float64
#  7   Quality check         36 non-null     object
#  8   97?                   413 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 29.2+ KB

# %%
#CNPJ
# df_fe['cnpj_int'] = df_fe['cnpj'].apply(np.int64)
df_fe['CNPJ_string'] = df_fe['CNPJ'].astype(str)
df_fe['CNPJ_Lenght'] = df_fe['CNPJ_string'].map(lambda calc: len(calc))
print("No. of characters in each word in the given series:")
df_fe['CNPJ_Lenght'].unique() #
# Out:
# No. of characters in each word in the given series:
# array([14, 13, 12,  3], dtype=int64)

# %%
df_fe[df_fe['CNPJ_Lenght']==13]
# Out:
#                                          Nome Fantasia  \
# 269                                     HOSPITAL REGER
# 270                                       CLINICA VIDA
# 271  CENTRO DE REABILITACAO RESIDENCIAL TERAPEUTICO...
# 272             CENTRO DE RECUPERACAO FILHOS DE ISRAEL
# 273                               ESPACO FLOR DA MANHA
# ..                                                 ...
# 397                      CLINICA DE REPOUSO DE GOIANIA
# 398                       CLINICA PSIQUIATRICA ITUPEVA
# 399                                    CLINICA RECANTO
# 400                                    CLINICA SINEURO
# 401                                             CEDRUS
#
#                                           Raz�o Social           CNPJ  \
# 269  HOSPITAL DE RETAGUARDA E REABILITACAO GERIATRI...  9646519000116
# 270           CLINICA VIDA ESPECIALIDADES MEDICAS LTDA  9562798000130
# 271  CENTRO DE REABILITACAO RESIDENCIAL TERAPEUTICO...  9300833000142
# ...
